# %%
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
models = [
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_1000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_5000_k_3",
    # "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_10000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_20000_k_3",
    # "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_50000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_100000_k_3",
]

plt.rcParams.update({"font.size": 18})

plt.figure(figsize=(10, 6))

for m in models:
    model_path = "/lustre/fs22/group/atlas/freder/hh/run/tomatos/" + m + "/"
    with open(model_path + "metrics.json", "r") as file:
        metrics = json.load(file)

    epoch_grid = range(1, len(metrics["cls_train"]) + 1)
    no_fold_m = m.split("_k_")[0]
    aux_str = ", slope=" + no_fold_m.split("_")[-1]
    plt.plot(epoch_grid, metrics["cls_train"], label=r"$CL_s$ train" + aux_str)

for m in models:
    model_path = "/lustre/fs22/group/atlas/freder/hh/run/tomatos/" + m + "/"
    with open(model_path + "metrics.json", "r") as file:
        metrics = json.load(file)

    epoch_grid = range(1, len(metrics["cls_train"]) + 1)
    no_fold_m = m.split("_k_")[0]
    aux_str = ", slope=" + no_fold_m.split("_")[-1]
    plt.plot(epoch_grid, metrics["cls_valid"], label=r"$CL_s$ valid" + aux_str)


plt.legend(prop={"size": 10}, ncols=2)  # prop={"size": 6})plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.xlabel("Epochs")
# plt.ylim([0.01, np.max(metrics["cls_train"])])
plt.ylim([0.014,0.025])
plt.tight_layout()
plot_path = "/lustre/fs22/group/atlas/freder/hh/run/plots/compare_loss_slope.pdf"
print(plot_path)
plt.show()
plt.savefig(plot_path)

plt.close()
# Out:
# /lustre/fs22/group/atlas/freder/hh/run/plots/compare_loss_slope.pdf

# %%
# models = [
#     "tomatos_cls_5_2000_study_2_lr_0p0005_bw_min_0p005_slope_1000_k_0",
#     "tomatos_cls_5_2000_study_2_lr_0p0005_bw_min_0p005_slope_5000_k_0",
#     "tomatos_cls_5_2000_study_2_lr_0p0005_bw_min_0p005_slope_10000_k_0",
#     "tomatos_cls_5_2000_study_2_lr_0p0005_bw_min_0p005_slope_20000_k_0",
#     "tomatos_cls_5_2000_study_2_lr_0p0005_bw_min_0p005_slope_50000_k_0",
#     "tomatos_cls_5_2000_study_2_lr_0p0005_bw_min_0p005_slope_100000_k_0",
# ]
models = [
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_1000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_5000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_10000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_20000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_50000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_100000_k_3",
]

plt.rcParams.update({"font.size": 18})

fig, ax1 = plt.subplots(figsize=(5.5, 5.5))

for m in models:
    model_path = "/lustre/fs22/group/atlas/freder/hh/run/tomatos/" + m + "/"
    with open(model_path + "metrics.json", "r") as file:
        metrics = json.load(file)

        no_fold_m = m.split("_k_")[0]
        aux_str = "m=" + no_fold_m.split("_")[-1]

        ax1.set_xlabel("Epoch")
        ax1.set_ylabel(r"$m_{jj}$ (GeV)")
        ax1.plot(np.array(metrics["vbf_cut"]) * 1e-3, label=aux_str)

        # ax1.set_ylabel(r"$|\Delta\eta(j,j)|$")
        # ax1.plot(np.array(metrics["eta_cut"]), label=aux_str)


fig.tight_layout()
plot_path = "/lustre/fs22/group/atlas/freder/hh/run/plots/cuts_slope_m_jj.pdf"
# plot_path = "/lustre/fs22/group/atlas/freder/hh/run/plots/cuts_slope_eta_jj.pdf"
# plt.legend(loc="upper right", prop={'size': 12})

# Position the legend with bbox_transform
ax1.legend(bbox_to_anchor=[0.9, 0.925], loc="upper right", prop={"size": 12})
# ax1.legend(bbox_to_anchor=[0.9, 0.825], loc="upper right", prop={"size": 12})
# plt.ylim(ax1.get_ylim())
# ax1.set_ylim(top=ax1.get_ylim()[1]*1.3)
print(plot_path)
plt.show()
plt.savefig(plot_path)
plt.close()
# Out:
# /lustre/fs22/group/atlas/freder/hh/run/plots/cuts_slope_m_jj.pdf

# %%
plt.figure(figsize=(10, 6))


for m in models:
    model_path = "/lustre/fs22/group/atlas/freder/hh/run/tomatos/" + m + "/"
    with open(model_path + "metrics.json", "r") as file:
        metrics = json.load(file)

    epoch_grid = range(1, len(metrics["cls_train"]) + 1)
    no_fold_m = m.split("_k_")[0]
    aux_str = ", slope=" + no_fold_m.split("_")[-1]
    plt.plot(epoch_grid, metrics["cls_train"], label=r"$CL_s$ train" + aux_str)

for m in models:
    model_path = "/lustre/fs22/group/atlas/freder/hh/run/tomatos/" + m + "/"
    with open(model_path + "metrics.json", "r") as file:
        metrics = json.load(file)

    epoch_grid = range(1, len(metrics["cls_train"]) + 1)
    no_fold_m = m.split("_k_")[0]
    aux_str = ", slope=" + no_fold_m.split("_")[-1]
    plt.plot(epoch_grid, metrics["cls_valid"], label=r"$CL_s$ valid" + aux_str)


plt.legend(prop={"size": 10}, ncols=2)  # prop={"size": 6})plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.ylim([0.01, np.max(metrics["cls_train"])])
plt.ylim([0.014, 0.025])
plt.tight_layout()
plot_path = "/lustre/fs22/group/atlas/freder/hh/run/plots/compare_loss_slope.pdf"
print(plot_path)
plt.savefig(plot_path)
plt.close()

models = [
    "tomatos_cls_5_2000_study_1_lr_0p0005_bw_min_0p001_slope_5000_k_3",
    "tomatos_cls_5_2000_study_1_lr_0p0005_bw_min_0p005_slope_5000_k_3",
    "tomatos_cls_5_2000_study_1_lr_0p0005_bw_min_0p01_slope_5000_k_3",
    # "tomatos_cls_5_2000_study_6_lr_0p0005_bw_min_0p0001_slope_20000_k_3",
]

plt.figure(figsize=(10, 6))
for m in models:

    model_path = "/lustre/fs22/group/atlas/freder/hh/run/tomatos/" + m + "/"
    with open(model_path + "metrics.json", "r") as file:
        metrics = json.load(file)
    n_bins = len(metrics["signal_approximation_diff"][0])

    total_sig_diff = (
        np.max(np.abs(np.array(metrics["signal_approximation_diff"]) - 1), axis=1) * 100
    )
    total_bkg_diff = (
        np.max(np.abs(np.array(metrics["bkg_approximation_diff"]) - 1), axis=1) * 100
    )
    no_fold_m = m.split("_slope")[0]

    aux_str = "bw min=" + no_fold_m.split("_")[-1] + ", "
    # plt.plot(
    #     total_sig_diff,
    #     label=aux_str + r"$\kappa_\mathrm{2V}=0$ signal",
    #     alpha=0.7,
    # )
    plt.plot(total_bkg_diff, label=aux_str + "Background Estimate", alpha=0.75)

plt.xlabel("Epoch")
plt.ylabel("Maximum Bin Deviation (%)")
plt.ylim([0, 10])
plt.legend()
plt.tight_layout()
plot_path = "/lustre/fs22/group/atlas/freder/hh/run/plots/compare_summed_diff_.pdf"
print(plot_path)
plt.savefig(plot_path)
plt.close()
# Out:
# /lustre/fs22/group/atlas/freder/hh/run/plots/compare_loss_slope.pdf
# /lustre/fs22/group/atlas/freder/hh/run/plots/compare_summed_diff_.pdf

# %%
plt.figure(figsize=(6, 5))
for m in models:
    model_path = "/lustre/fs22/group/atlas/freder/hh/run/tomatos/" + m + "/"
    with open(model_path + "metrics.json", "r") as file:
        metrics = json.load(file)

    epoch_grid = range(1, len(metrics["cls_train"]) + 1)

    no_fold_m = m.split("_slope")[0]

    aux_str = "bw min=" + no_fold_m.split("_")[-1]

    plt.plot(epoch_grid, metrics["bw"], label=aux_str)

plt.xlabel("Epoch")
plt.ylabel("Bandwidth")
plt.legend()
plt.tight_layout()
plot_path = "/lustre/fs22/group/atlas/freder/hh/run/plots/bandwidths_bw_min.pdf"
print(plot_path)
plt.savefig(plot_path)
plt.close()


plt.figure(figsize=(10, 6))
for m in models:
    model_path = "/lustre/fs22/group/atlas/freder/hh/run/tomatos/" + m + "/"
    with open(model_path + "metrics.json", "r") as file:
        metrics = json.load(file)

    epoch_grid = range(1, len(metrics["cls_train"]) + 1)
    no_fold_m = m.split("_slope")[0]
    aux_str = ", bw min=" + no_fold_m.split("_")[-1]
    plt.plot(epoch_grid, metrics["cls_train"], label=r"$CL_s$ train" + aux_str)

for m in models:
    model_path = "/lustre/fs22/group/atlas/freder/hh/run/tomatos/" + m + "/"
    with open(model_path + "metrics.json", "r") as file:
        metrics = json.load(file)

    epoch_grid = range(1, len(metrics["cls_train"]) + 1)
    no_fold_m = m.split("_slope")[0]
    aux_str = ", bw min=" + no_fold_m.split("_")[-1]
    plt.plot(epoch_grid, metrics["cls_valid"], label=r"$CL_s$ valid" + aux_str)


plt.legend(ncols=2)  # prop={"size": 6})plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.ylim([0.01, np.max(metrics["cls_train"])])
plt.tight_layout()
plot_path = "/lustre/fs22/group/atlas/freder/hh/run/plots/compare_loss_bw.pdf"
print(plot_path)
plt.savefig(plot_path)
plt.close()
# Out:
# /lustre/fs22/group/atlas/freder/hh/run/plots/bandwidths_bw_min.pdf
# /lustre/fs22/group/atlas/freder/hh/run/plots/compare_loss_bw.pdf

# %%
models = [
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_1000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_5000_k_3",
    # "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_10000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_20000_k_3",
    # "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_50000_k_3",
    # "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_100000_k_3",
]


plt.figure(figsize=(10, 6))
for m in models:

    model_path = "/lustre/fs22/group/atlas/freder/hh/run/tomatos/" + m + "/"
    with open(model_path + "metrics.json", "r") as file:
        metrics = json.load(file)
    n_bins = len(metrics["signal_approximation_diff"][0])

    total_sig_diff = (
        np.max(np.abs(np.array(metrics["signal_approximation_diff"]) - 1), axis=1) * 100
    )
    total_bkg_diff = (
        np.max(np.abs(np.array(metrics["bkg_approximation_diff"]) - 1), axis=1) * 100
    )
    
    no_fold_m = m.split("_k_3")[0]
    aux_str = "m=" + no_fold_m.split("_slope_")[-1] + ", "
    # plt.plot(
    #     total_sig_diff,
    #     label=aux_str + r"$\kappa_\mathrm{2V}=0$ signal",
    #     alpha=0.7,
    # )
    plt.plot(total_bkg_diff, label=aux_str + "Background Estimate", alpha=0.75)

plt.xlabel("Epoch")
plt.ylabel("Maximum Bin Deviation (%)")
plt.ylim([0, 10])
plt.legend()
plt.tight_layout()
plot_path = "/lustre/fs22/group/atlas/freder/hh/run/plots/compare_summed_diff_slope_bkg.pdf"
print(plot_path)
plt.show()
plt.savefig(plot_path)
plt.close()
# Out:
# /lustre/fs22/group/atlas/freder/hh/run/plots/compare_summed_diff_slope_bkg.pdf

# %%
models = [
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_1000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_5000_k_3",
    # "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_10000_k_3",
    "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_20000_k_3",
    # "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_50000_k_3",
    # "tomatos_cls_5_2000_study_7_lr_0p0005_bw_min_0p005_slope_100000_k_3",
]


plt.figure(figsize=(10, 6))
for m in models:

    model_path = "/lustre/fs22/group/atlas/freder/hh/run/tomatos/" + m + "/"
    with open(model_path + "metrics.json", "r") as file:
        metrics = json.load(file)
    n_bins = len(metrics["signal_approximation_diff"][0])

    total_sig_diff = (
        np.max(np.abs(np.array(metrics["signal_approximation_diff"]) - 1), axis=1) * 100
    )
    total_bkg_diff = (
        np.max(np.abs(np.array(metrics["bkg_approximation_diff"]) - 1), axis=1) * 100
    )
    
    no_fold_m = m.split("_k_3")[0]
    aux_str = "m=" + no_fold_m.split("_slope_")[-1] + ", "
    plt.plot(
        total_sig_diff,
        label=aux_str + r"$\kappa_\mathrm{2V}=0$ signal",
        alpha=0.7,
    )

plt.xlabel("Epoch")
plt.ylabel("Maximum Bin Deviation (%)")
plt.ylim([0, 10])
plt.legend()
plt.tight_layout()
plot_path = "/lustre/fs22/group/atlas/freder/hh/run/plots/compare_summed_diff_slope_signal.pdf"
print(plot_path)
plt.show()
plt.savefig(plot_path)
plt.close()
# Out:
# /lustre/fs22/group/atlas/freder/hh/run/plots/compare_summed_diff_slope_signal.pdf
